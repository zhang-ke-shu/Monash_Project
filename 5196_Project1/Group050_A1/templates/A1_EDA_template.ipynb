# %% [markdown]
# # FIT5196 Assessment 1 - EDA Notebook Template
#
# **Group:** GroupNNN
# **Members:** Replace with names and student IDs
#
# Rename this file to `GroupNNN_EDA.ipynb`. Use it to create the submitted
# `GroupNNN_EDA.pdf`. The notebook is reproducibility evidence; the PDF is the
# readable assessed report. Remove unused prompts before export.

# %% [markdown]
# ## 0. Configuration and data loading
#
# Load the six standardised CSVs produced by the solution notebook. Keep paths
# relative/configurable and use explicit read options where the literal string
# `NaN` must remain visible.

# %%
from pathlib import Path

GROUP_ID = "GroupNNN"
OUTPUT_DIR = Path("outputs")

# %% [markdown]
# ## 1. Context and data-preparation assurance
#
# Briefly define the business context and data scope. Summarise 3-5 material
# transformation decisions and 4-6 material validation results by citing stable
# `MAP-...` and `VAL-...` IDs. Do not repeat the complete mapping or notebook.

# %% [markdown]
# Replace with the concise assurance narrative.

# %% [markdown]
# ## 2. Assessed EDA visualisations
#
# Submit 6-8 clearly labelled assessed figures. Across the set, cover all six
# published categories, at least four tables and at least two valid relational
# analyses. For each figure state the question, observation unit, denominator,
# tables/join keys, interpretation and material limitation.

# %% [markdown]
# ### Figure 1: Univariate distribution or composition
#
# **Question:** Replace.
# **Observation unit and denominator:** Replace.
# **Tables and join keys:** Replace.
# **Interpretation and limitation:** Replace after producing the figure.

# %% [markdown]
# ### Figure 2: Bivariate relationship or group comparison
#
# **Question:** Replace.
# **Observation unit and denominator:** Replace.
# **Tables and join keys:** Replace.
# **Interpretation and limitation:** Replace after producing the figure.

# %% [markdown]
# ### Figure 3: Multivariate or segmented relationship
#
# **Question:** Replace.
# **Observation unit and denominator:** Replace.
# **Tables and join keys:** Replace.
# **Interpretation and limitation:** Replace after producing the figure.

# %% [markdown]
# ### Figure 4: Temporal pattern
#
# **Question:** Replace.
# **Observation unit and denominator:** Replace.
# **Tables and join keys:** Replace.
# **Interpretation and limitation:** Replace after producing the figure.

# %% [markdown]
# ### Figure 5: Review or text behaviour
#
# **Question:** Replace.
# **Observation unit and denominator:** Replace.
# **Tables and join keys:** Replace.
# **Interpretation and limitation:** Replace after producing the figure.

# %% [markdown]
# ### Figure 6: Delivery or operational performance
#
# **Question:** Replace.
# **Observation unit and denominator:** Replace.
# **Tables and join keys:** Replace.
# **Interpretation and limitation:** Replace after producing the figure.

# %% [markdown]
# ### Optional Figure 7-8
#
# Add no more than two further assessed figures when they contribute a distinct
# question. Delete this section when unused. A coordinated subplot answering one
# shared question counts as one figure.

# %% [markdown]
# ## 3. Ten evidence-based findings
#
# Write exactly ten numbered findings. Keep each concise and decision-focused.
# Each must identify the evidence, grain, magnitude/denominator, business meaning,
# an alternative explanation or uncertainty, and a proportionate implication.
# One figure may support more than one genuinely distinct finding.

# %% [markdown]
# 1. **Finding 1:** Replace.
# 2. **Finding 2:** Replace.
# 3. **Finding 3:** Replace.
# 4. **Finding 4:** Replace.
# 5. **Finding 5:** Replace.
# 6. **Finding 6:** Replace.
# 7. **Finding 7:** Replace.
# 8. **Finding 8:** Replace.
# 9. **Finding 9:** Replace.
# 10. **Finding 10:** Replace.

# %% [markdown]
# ## 4. Five future machine-learning questions
#
# Write exactly five numbered questions covering at least two problem types.
# Model training is not required. Keep each response compact enough for the
# ten-page report.

# %% [markdown]
# ### MLQ-1: Replace with a specific question
#
# | Element | Response |
# |---|---|
# | EDA evidence | Cite a figure/finding and quantified observation |
# | Business decision | Replace |
# | Problem type and analysis unit | Replace |
# | Target or unsupervised objective | Replace |
# | Decision-time predictors | Replace |
# | Validation split and metric | Replace and justify |
# | Leakage, fairness or deployment risk | Replace |

# %% [markdown]
# ### MLQ-2: Replace with a specific question
#
# | Element | Response |
# |---|---|
# | EDA evidence | Cite a figure/finding and quantified observation |
# | Business decision | Replace |
# | Problem type and analysis unit | Replace |
# | Target or unsupervised objective | Replace |
# | Decision-time predictors | Replace |
# | Validation split and metric | Replace and justify |
# | Leakage, fairness or deployment risk | Replace |

# %% [markdown]
# ### MLQ-3: Replace with a specific question
#
# | Element | Response |
# |---|---|
# | EDA evidence | Cite a figure/finding and quantified observation |
# | Business decision | Replace |
# | Problem type and analysis unit | Replace |
# | Target or unsupervised objective | Replace |
# | Decision-time predictors | Replace |
# | Validation split and metric | Replace and justify |
# | Leakage, fairness or deployment risk | Replace |

# %% [markdown]
# ### MLQ-4: Replace with a specific question
#
# | Element | Response |
# |---|---|
# | EDA evidence | Cite a figure/finding and quantified observation |
# | Business decision | Replace |
# | Problem type and analysis unit | Replace |
# | Target or unsupervised objective | Replace |
# | Decision-time predictors | Replace |
# | Validation split and metric | Replace and justify |
# | Leakage, fairness or deployment risk | Replace |

# %% [markdown]
# ### MLQ-5: Replace with a specific question
#
# | Element | Response |
# |---|---|
# | EDA evidence | Cite a figure/finding and quantified observation |
# | Business decision | Replace |
# | Problem type and analysis unit | Replace |
# | Target or unsupervised objective | Replace |
# | Decision-time predictors | Replace |
# | Validation split and metric | Replace and justify |
# | Leakage, fairness or deployment risk | Replace |

# %% [markdown]
# ## 5. Limitations and conclusion
#
# Summarise the most decision-relevant limitations, what the data cannot establish
# and the next evidence needed. End with a concise conclusion rather than new
# analysis.

# %% [markdown]
# Replace with limitations and conclusion.

# %% [markdown]
# ## References
#
# Use one consistent referencing style for external facts, code, data and ideas.
