# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # **Week 2 Applied Session: Data Discovery & Collection**

# %% [markdown]
# In two parts:
# * reproducing the DataWrangler process (using the same 'Air crashes' data) and
# * bad, bad data investigations

# %% [markdown]
# ** Before you start, a most important thing to do, check your python version**

# %%
import sys
print (sys.version_info)
# Out:
# sys.version_info(major=3, minor=11, micro=11, releaselevel='final', serial=0)

# %%
import pandas as pd # not the bamboo eating bear... 'Panel Data'

# %% [markdown]
# # Part 1
# ## Step 1 Read data

# %%
# load data
df = pd.read_csv('/content/drive/Shareddrives/FIT5196_S2_2026/Week2/AirCrashes_raw.csv') # df is a dataframe, confirm with: type(df)
df.shape
# Out:
# (927, 1)

# %% [markdown]
# #### How many lines of data?
# #### How many did you get with DataWrangler?
#
# Have a look a the first few rows:

# %%
#df[0:2] or
df.head(20)
# Out:
#                                                    Incident American Airlines Flight 11 involving a Boeing 767-223ER in 2001
# Casualties                                                                             Extremely High
# Total Dead                                                                                       1692
# Crew                                                                                               11
# Passengers                                                                                         81
# Ground                                                                                           1600
# Notes                                                                                    No survivors
# Type                                                                                              INH
# Reason                                                                                         Attack
# Location                                                                     New York - New York - US
# Country                                                                                            US
# Phase                                                                                             ENR
# Date                                                                                       2001-09-11
# Latitude                                                                                   40.7143528
# Longitude                                                                                 -74.0059731
# Circumstances                                                                  Good Visibility by Day
# Incident United Airlines Flight 175 involving a...                                                NaN
# Casualties                                                                             Extremely High
# Total Dead                                                                                        965
# Crew                                                                                                9
# Passengers                                                                                         56

# %% [markdown]
# That's not quite right.. the first line has been stolen for the title/header
# #### Does read_csv ignore empty lines?
# e.g. line 18 should be blank
#
# skip_blank_lines = True (the default) see:
#
# https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html
#
# Try again, force our own headers upon the data using default column names from DataWrangler (split/extract etc.)
#
# This pushes the first incident down into the data where it belongs (but adds a NaN, below)

# %%
df = pd.read_csv('/content/drive/Shareddrives/FIT5196_S2_2026/Week2/AirCrashes_raw.csv', names = ['split', 'split1'])
# column names (split, split1) replicate DataWrangler column names
df.head(10)
# Out:
#                                                split                    split1
# 0  Incident American Airlines Flight 11 involving...                       NaN
# 1                                         Casualties            Extremely High
# 2                                         Total Dead                      1692
# 3                                               Crew                        11
# 4                                         Passengers                        81
# 5                                             Ground                      1600
# 6                                              Notes              No survivors
# 7                                               Type                       INH
# 8                                             Reason                    Attack
# 9                                           Location  New York - New York - US

# %% [markdown]
# ## Step 2 Extract index(s)
#
# ### Extract flight information

# %%
# now extract flights based on one of the suggestions from DataWrangler
df['split'].str.extract("Incident(.*)involving")
# treat the 'split' column as a str, then
# use the extract method on the str
# Out:
#                                  0
# 0     American Airlines Flight 11
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                              NaN
# ..                             ...
# 923                            NaN
# 924                            NaN
# 925                            NaN
# 926                            NaN
# 927                            NaN
#
# [928 rows x 1 columns]

# %% [markdown]
# ### That seems to have worked...
#
# We got 'American Airlines Flight 11' and 'United Airlines Flight 175' etc but lost all the other data and gained a bunch of NaNs
#
# #### What is this 'str.extract' code anyway? (add a comment to decode or explain it)
#
# extract("Incident (.*) involving")
#
# ### But we want planes in a new column, we can create one called 'extract' like this:
#
# df['extract'] = df['split'].str.extract("Incident (.*) involving")
#
# But this would be the last column, we want it in the second (location is not critical but it can be done so why not).
#
# Try this:

# %%
df.head()
# Out:
#                                                split          split1
# 0  Incident American Airlines Flight 11 involving...             NaN
# 1                                         Casualties  Extremely High
# 2                                         Total Dead            1692
# 3                                               Crew              11
# 4                                         Passengers              81

# %%
df.insert(1, column = 'extract', value = df['split'].str.extract("Incident (.*) involving",expand= True))
# have a go at commenting this line of code too

# %%
df.head(20)
# Out:
#                                                 split  \
# 0   Incident American Airlines Flight 11 involving...
# 1                                          Casualties
# 2                                          Total Dead
# 3                                                Crew
# 4                                          Passengers
# 5                                              Ground
# 6                                               Notes
# 7                                                Type
# 8                                              Reason
# 9                                            Location
# 10                                            Country
# 11                                              Phase
# 12                                               Date
# 13                                           Latitude
# 14                                          Longitude
# 15                                      Circumstances
# 16  Incident United Airlines Flight 175 involving ...
# 17                                         Casualties
# 18                                         Total Dead
# 19                                               Crew
#
#                         extract                    split1
# 0   American Airlines Flight 11                       NaN
# 1                           NaN            Extremely High
# 2                           NaN                      1692
# 3                           NaN                        11
# 4                           NaN                        81
# 5                           NaN                      1600
# 6                           NaN              No survivors
# 7                           NaN                       INH
# 8                           NaN                    Attack
# 9                           NaN  New York - New York - US
# 10                          NaN                        US
# 11                          NaN                       ENR
# 12                          NaN                2001-09-11
# 13                          NaN                40.7143528
# 14                          NaN               -74.0059731
# 15                          NaN    Good Visibility by Day
# 16   United Airlines Flight 175                       NaN
# 17                          NaN            Extremely High
# 18                          NaN                       965
# 19                          NaN                         9

# %% [markdown]
# So there's the flight information in it's own column, plus a whole lot of NaNs
#
# We could replace all the NaN with spaces or similar but they can wait
#
# Now we want the aircraft in it's own column, similar to above,
# based on the suggestion from DataWrangler, note spaces in "\ a (.*)\ in "
#
# #### but is this optimal?

# %%
# and repeat to get the aircraft type
df.insert(1, 'extract1', df['split'].str.extract(" a (.*) in ",expand= True))
# and df.head(20) to confirm
df.head(20)
# Out:
#                                                 split          extract1  \
# 0   Incident American Airlines Flight 11 involving...  Boeing 767-223ER
# 1                                          Casualties               NaN
# 2                                          Total Dead               NaN
# 3                                                Crew               NaN
# 4                                          Passengers               NaN
# 5                                              Ground               NaN
# 6                                               Notes               NaN
# 7                                                Type               NaN
# 8                                              Reason               NaN
# 9                                            Location               NaN
# 10                                            Country               NaN
# 11                                              Phase               NaN
# 12                                               Date               NaN
# 13                                           Latitude               NaN
# 14                                          Longitude               NaN
# 15                                      Circumstances               NaN
# 16  Incident United Airlines Flight 175 involving ...    Boeing 767-222
# 17                                         Casualties               NaN
# 18                                         Total Dead               NaN
# 19                                               Crew               NaN
#
#                         extract                    split1
# 0   American Airlines Flight 11                       NaN
# 1                           NaN            Extremely High
# 2                           NaN                      1692
# 3                           NaN                        11
# 4                           NaN                        81
# 5                           NaN                      1600
# 6                           NaN              No survivors
# 7                           NaN                       INH
# 8                           NaN                    Attack
# 9                           NaN  New York - New York - US
# 10                          NaN                        US
# 11                          NaN                       ENR
# 12                          NaN                2001-09-11
# 13                          NaN                40.7143528
# 14                          NaN               -74.0059731
# 15                          NaN    Good Visibility by Day
# 16   United Airlines Flight 175                       NaN
# 17                          NaN            Extremely High
# 18                          NaN                       965
# 19                          NaN                         9

# %% [markdown]
# Drop the empty lines

# %%
df = df.dropna(how='all')

# %%
df
# Out:
#                                                  split          extract1  \
# 0    Incident American Airlines Flight 11 involving...  Boeing 767-223ER
# 1                                           Casualties               NaN
# 2                                           Total Dead               NaN
# 3                                                 Crew               NaN
# 4                                           Passengers               NaN
# ..                                                 ...               ...
# 923                                              Phase               NaN
# 924                                               Date               NaN
# 925                                           Latitude               NaN
# 926                                          Longitude               NaN
# 927                                      Circumstances               NaN
#
#                          extract                   split1
# 0    American Airlines Flight 11                      NaN
# 1                            NaN           Extremely High
# 2                            NaN                     1692
# 3                            NaN                       11
# 4                            NaN                       81
# ..                           ...                      ...
# 923                          NaN                      APR
# 924                          NaN               1995-12-20
# 925                          NaN                      3.9
# 926                          NaN                    -76.3
# 927                          NaN  Bad Visibility by Night
#
# [928 rows x 4 columns]

# %% [markdown]
# ## Step 3  'Fill down'
#
# We want to 'fill down' the indexes  (e.g. lines 1 to 15 should be associated with line 0)
#
# There are several options
# * na.locf() method from zoo package.
# * ddply() from plyr
# * bfill()
# * fillna()

# %%
df = df.fillna(method = 'pad') # magic, take the previous value (not NaN) and fill down

# https://pandas.pydata.org/docs/user_guide/missing_data.html
# Out:
# <ipython-input-22-86593a9a725a>:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df = df.fillna(method = 'pad') # magic, take the previous value (not NaN) and fill down

# %%
df.head(200)
# Out:
#                                                  split          extract1  \
# 0    Incident American Airlines Flight 11 involving...  Boeing 767-223ER
# 1                                           Casualties  Boeing 767-223ER
# 2                                           Total Dead  Boeing 767-223ER
# 3                                                 Crew  Boeing 767-223ER
# 4                                           Passengers  Boeing 767-223ER
# ..                                                 ...               ...
# 195                                               Crew   Boeing 747-230B
# 196                                         Passengers   Boeing 747-230B
# 197                                             Ground   Boeing 747-230B
# 198                                              Notes   Boeing 747-230B
# 199                                               Type   Boeing 747-230B
#
#                          extract          split1
# 0    American Airlines Flight 11             NaN
# 1    American Airlines Flight 11  Extremely High
# 2    American Airlines Flight 11            1692
# 3    American Airlines Flight 11              11
# 4    American Airlines Flight 11              81
# ..                           ...             ...
# 195  Korean Air Lines Flight 007              23
# 196  Korean Air Lines Flight 007             246
# 197  Korean Air Lines Flight 007               0
# 198  Korean Air Lines Flight 007    No survivors
# 199  Korean Air Lines Flight 007             EXS
#
# [200 rows x 4 columns]

# %% [markdown]
# ## Step 4 Remove the index row
#
# We need to delete all the 'incident' rows, they have served their purpose and are now redundant.

# %%
# use str.contain function to get the row index.
# keep everything that doesn't have "Incident" in it
df = df[df['split'].str.contains("Incident") == False]
# do we need to worry about a plane called "Incident" or "Incident weather" etc???

# %%
# and check with e.g. df.shape
print (df.shape)
df
# Out:
# (870, 4)
#              split          extract1                       extract  \
# 1       Casualties  Boeing 767-223ER   American Airlines Flight 11
# 2       Total Dead  Boeing 767-223ER   American Airlines Flight 11
# 3             Crew  Boeing 767-223ER   American Airlines Flight 11
# 4       Passengers  Boeing 767-223ER   American Airlines Flight 11
# 5           Ground  Boeing 767-223ER   American Airlines Flight 11
# ..             ...               ...                           ...
# 923          Phase    Boeing Tu-154M  American Airlines Flight 965
# 924           Date    Boeing Tu-154M  American Airlines Flight 965
# 925       Latitude    Boeing Tu-154M  American Airlines Flight 965
# 926      Longitude    Boeing Tu-154M  American Airlines Flight 965
# 927  Circumstances    Boeing Tu-154M  American Airlines Flight 965
#
#                       split1
# 1             Extremely High
# 2                       1692
# 3                         11
# 4                         81
# 5                       1600
# ..                       ...
# 923                      APR
# 924               1995-12-20
# 925                      3.9
# 926                    -76.3
# 927  Bad Visibility by Night
#
# [870 rows x 4 columns]

# %% [markdown]
# ## Now to 'unfold', there are several options
#
# * melt()
# * stack, unstack?
# * pivot_table()
# * pivot()
#
# https://pandas.pydata.org/docs/user_guide/reshaping.html

# %%
# data = df.pivot('extract', 'split', 'split1')
# the parameters above are (left to right) index, columns, values
# You can also write it like this:
data = df.pivot(index = 'extract', columns = 'split', values = 'split1')

# %%
data.shape
# Out:
# (58, 15)

# %%
data.head() # 58 records, good, but lost plane type, bad
# where's 'extract1' - can we have multiple indexes or have to put that data back in?
# Out:
# split                               Casualties            Circumstances  \
# extract
# Aeroflot Flight 217             Extremely High    Bad Visibility by Day
# Aeroflot Flight 3352            Extremely High  Bad Visibility by Night
# Aeroflot Flight 4227            Extremely High  Bad Visibility by Night
# Aeroflot Flight 7425            Extremely High  Bad Visibility by Night
# Aeroflot/Moldovia (CCCP-65816)  Extremely High  Bad Visibility by Night
#
# split                              Country Crew        Date Ground  \
# extract
# Aeroflot Flight 217                 Russia   10  1972-10-13      0
# Aeroflot Flight 3352                Russia    5  1984-10-11      4
# Aeroflot Flight 4227            Kazakhstan   10  1890-07-08      0
# Aeroflot Flight 7425            Uzbekistan    9  1985-07-10      0
# Aeroflot/Moldovia (CCCP-65816)  Kazakhstan   13  1979-08-11      0
#
# split                             Latitude               Location   Longitude  \
# extract
# Aeroflot Flight 217              55.755826        Moscow - Russia     37.6173
# Aeroflot Flight 3352            54.9666667          Omsk - Russia  73.3833333
# Aeroflot Flight 4227             43.255058    Almaty - Kazakhstan   76.912628
# Aeroflot Flight 7425            42.1566667  Uchkuduk - Uzbekistan  63.5555556
# Aeroflot/Moldovia (CCCP-65816)     48.8125    Saykyn - Kazakhstan  46.7636111
#
# split                                    Notes Passengers Phase    Reason  \
# extract
# Aeroflot Flight 217               No survivors        164   APR  Accident
# Aeroflot Flight 3352            Some survivors        169   LDG  Accident
# Aeroflot Flight 4227              No survivors        156   ENR  Accident
# Aeroflot Flight 7425              No survivors        191   ENR  Accident
# Aeroflot/Moldovia (CCCP-65816)    No survivors        165   ENR  Accident
#
# split                          Total Dead Type
# extract
# Aeroflot Flight 217                   174  COM
# Aeroflot Flight 3352                  178  COM
# Aeroflot Flight 4227                  166  COM
# Aeroflot Flight 7425                    0  COM
# Aeroflot/Moldovia (CCCP-65816)        178  COM

# %% [markdown]
# ### Problem:
#
# we have two columns we want to pivot on, 'extract' & 'extract1' (AKA flight & plane) but
#
# pivot() can't have multiple indexes...
#
# e.g. df.pivot(index = ['extract','extract1'], 'split', 'split1') # error
#
# pivot_table() can but insists on doing some accounting or aggreagating too, like sum or avg, which we don't need
#
# e.g. pd.pivot_table(df, values='split1', index = ['extract','extract1'], columns='split') # error, no function
#
# ### Solutions?
#
# use pivot() then force the other column back into the data??
#
# or trick pivot_table() into doing some pointless accounting (that adds up to nothing)??
#
# try something else... stack, unstack, group, dplyr?
#
# DIY code??
#
#
#
# *(Image previously hosted at desktopimages.org is no longer available.)*

# %%
# solution: make the function a copy, x = x
# data = pd.pivot_table(df, index=["extract"], columns = 'split', values = 'split1', aggfunc = lambda x: x)
# or
data = pd.pivot_table(df, index=["extract"], columns = 'split', values = 'split1', aggfunc = 'max')
# ha, cop that
# https://stackoverflow.com/questions/19279229/pandas-pivot-table-with-non-numeric-values-dataerror-no-numeric-types-to-ag

data # not using df anymore, keep it as backup
# Out:
# split                                           Casualties  \
# extract
# Aeroflot Flight 217                         Extremely High
# Aeroflot Flight 3352                        Extremely High
# Aeroflot Flight 4227                        Extremely High
# Aeroflot Flight 7425                        Extremely High
# Aeroflot/Moldovia (CCCP-65816)              Extremely High
# African Air (RA-26222)                      Extremely High
# Air France Flight 447                       Extremely High
# Air India Flight 182                        Extremely High
# Air India Flight 855                        Extremely High
# Air New Zealand Flight 901                  Extremely High
# Alas Nacionales Flight 301                  Extremely High
# Alia Royal Jordanian (JY-AEE)               Extremely High
# All Nippon Airways Flight 58 and            Extremely High
# American Airlines Flight 11                 Extremely High
# American Airlines Flight 191                Extremely High
# American Airlines Flight 587                Extremely High
# American Airlines Flight 77                 Extremely High
# American Airlines Flight 965                Extremely High
# Arrow Air Flight 1285                       Extremely High
# Avianca Flight 011                          Extremely High
# British Airways Flight 476 and              Extremely High
# Caspian Airlines Flight 7908                Extremely High
# China Airlines Flight 140                   Extremely High
# China Airlines Flight 611                   Extremely High
# China Airlines Flight 676                   Extremely High
# China Northwest Airlines Flight 2303        Extremely High
# Cubana de Aviación Flight 9646              Extremely High
# Dana Air Flight 992                         Extremely High
# EgyptAir Flight 990                         Extremely High
# Garuda Indonesia Flight 152                 Extremely High
# Icelandic Airlines Flight LL 001            Extremely High
# Inex-Adria Aviopromet Flight 1308           Extremely High
# Iran Air Flight 655                         Extremely High
# Iranian Air Force (15-2280)                 Extremely High
# Japan Airlines Flight 123                   Extremely High
# Kenya Airways Flight 431                    Extremely High
# Korean Air Flight 801                       Extremely High
# Korean Air Lines Flight 007                 Extremely High
# LOT Flight 5055                             Extremely High
# Lauda Air Flight 004                        Extremely High
# Martinair Holland Flight 138                Extremely High
# Mexicana Flight 940                         Extremely High
# Nigeria Airways (JY-ADO)                    Extremely High
# Nigeria Airways Flight 2120                 Extremely High
# Pakistan International Airlines Flight 268  Extremely High
# Pan Am Flight 103                           Extremely High
# Pan Am Flight 1736 and KLM Flight 4805      Extremely High
# Pulkovo Flight 612                          Extremely High
# Saudi Arabian Flight 763 and                Extremely High
# Saudia Flight 163                           Extremely High
# Surinam Airways Flight 764                  Extremely High
# Saudi Arabian Flight 763 and                                            Charkhi Dadri - India
# Saudia Flight 163                                                       Riyadh - Saudi Arabia
# Surinam Airways Flight 764                                               Paramaribo - Surinam
# Swissair Flight 111                              Atlantic Ocean - Peggys Cove - N.S. - Canada
# TAM Airlines Flight 3054                                                   Sao Paulo - Brazil
# TWA Flight 800                                 Atlantic Ocean - East Moriches - New York - US
# Turkish Airlines Flight 981                                         Fontaine-Chaalis - France
# Union de Transportes Aériens Flight 772                                        Tenere - Niger
# United Airlines Flight 175                                           New York - New York - US
# West Caribbean Airways Flight 708                                       Machiques - Venezuela
#
# split                                          Longitude           Notes  \
# extract
# Aeroflot Flight 217                              37.6173    No survivors
# Aeroflot Flight 3352                          73.3833333  Some survivors
# Aeroflot Flight 4227                           76.912628    No survivors
# Aeroflot Flight 7425                          63.5555556    No survivors
# Aeroflot/Moldovia (CCCP-65816)                46.7636111    No survivors
# African Air (RA-26222)                        15.3138889  Some survivors
# Air France Flight 447                         -30.561667    No survivors
# Air India Flight 182                          -8.4863157    No survivors
# Air India Flight 855                          72.8776559    No survivors
# Air New Zealand Flight 901                   167.0757008    No survivors
# Alas Nacionales Flight 301                   -70.6871091    No survivors
# Alia Royal Jordanian (JY-AEE)                 -9.8208632    No survivors
# All Nippon Airways Flight 58 and             140.9757756    One survivor
# American Airlines Flight 11                  -74.0059731    No survivors
# American Airlines Flight 191                 -87.8833991    No survivors
# American Airlines Flight 587                 -73.8481906    No survivors
# American Airlines Flight 77                  -77.1067698    No survivors
# American Airlines Flight 965                       -76.3  Some survivors
# Arrow Air Flight 1285                        -54.6103488    No survivors
# Avianca Flight 011                            -3.7037902  Some survivors
# British Airways Flight 476 and                 16.416766    No survivors
# Caspian Airlines Flight 7908                   50.003811    No survivors
# China Airlines Flight 140                    136.9109515  Some survivors
# China Airlines Flight 611                    119.5052778    No survivors
# China Airlines Flight 676                     121.193945    No survivors
# China Northwest Airlines Flight 2303          108.940175    No survivors
# Cubana de Aviación Flight 9646                -82.388557    No survivors
# Dana Air Flight 992                             3.417977    No survivors
# EgyptAir Flight 990                           -70.099451    No survivors
# Garuda Indonesia Flight 152                   98.6755979    No survivors
# Icelandic Airlines Flight LL 001              79.8912813  Some survivors
# Inex-Adria Aviopromet Flight 1308              8.9916667    No survivors
# Iran Air Flight 655                           56.4719928    No survivors
# Iranian Air Force (15-2280)                     57.06702    No survivors
# Japan Airlines Flight 123                    139.7742683  Some survivors
# Kenya Airways Flight 431                        3.743509  Some survivors
# Korean Air Flight 801                        144.7454685  Some survivors
# Korean Air Lines Flight 007                  141.2333333    No survivors
# LOT Flight 5055                               21.0122287    No survivors
# Lauda Air Flight 004                          99.4490951    No survivors
# Martinair Holland Flight 138                  80.5709256    No survivors
# Mexicana Flight 940                         -100.4233685    No survivors
# Nigeria Airways (JY-ADO)                        8.516667  Some survivors
# Nigeria Airways Flight 2120                   39.1727778    No survivors
# Pakistan International Airlines Flight 268    85.3333333    No survivors
# Pan Am Flight 103                              -3.349008    No survivors
# Pan Am Flight 1736 and KLM Flight 4805       -16.6291304  Some survivors
# Saudia Flight 163                                 287   ENR  Accident
# Surinam Airways Flight 764                        167   APR  Accident
# Swissair Flight 111                               215   ENR  Accident
# TAM Airlines Flight 3054                          181   LDG  Accident
# TWA Flight 800                                    212   ENR  Accident
# Turkish Airlines Flight 981                       335   ENR  Accident
# Union de Transportes Aériens Flight 772           156   ENR    Attack
# United Airlines Flight 175                         56   ENR    Attack
# West Caribbean Airways Flight 708                 152   ENR  Accident
#
# split                                      Total Dead Type
# extract
# Aeroflot Flight 217                               174  COM
# Aeroflot Flight 3352                              178  COM
# Aeroflot Flight 4227                              166  COM
# Aeroflot Flight 7425                                0  COM
# Aeroflot/Moldovia (CCCP-65816)                    178  COM
# African Air (RA-26222)                             37  COM
# Air France Flight 447                             228  COM
# Air India Flight 182                              329  INB
# Air India Flight 855                              213  COM
# Air New Zealand Flight 901                        257  COM
# Alas Nacionales Flight 301                        189  COM
# Alia Royal Jordanian (JY-AEE)                     188  COM
# All Nippon Airways Flight 58 and                  162  COM
# American Airlines Flight 11                      1692  INH
# American Airlines Flight 191                      273  COM
# American Airlines Flight 587                      265  COM
# American Airlines Flight 77                       189  INH
# American Airlines Flight 965                      159  COM
# Arrow Air Flight 1285                             256  COM
# Avianca Flight 011                                181  COM
# British Airways Flight 476 and                    177  COM
# Caspian Airlines Flight 7908                      168  COM
# China Airlines Flight 140                         264  COM
# China Airlines Flight 611                         225  COM
# China Airlines Flight 676                         202  COM
# China Northwest Airlines Flight 2303              150  COM
# Cubana de Aviación Flight 9646                    171  COM
# Dana Air Flight 992                               163  COM
# EgyptAir Flight 990                               217  COM
# Garuda Indonesia Flight 152                       234  COM
# Icelandic Airlines Flight LL 001                  183  COM
# Inex-Adria Aviopromet Flight 1308                 180  COM
# Iran Air Flight 655                               290  EXG
# Iranian Air Force (15-2280)                       275  MIL
# Japan Airlines Flight 123                         520  COM
# Kenya Airways Flight 431                          169  COM
# Korean Air Flight 801                             228  COM
# Korean Air Lines Flight 007                       269  EXS
# LOT Flight 5055                                   183  COM
# Lauda Air Flight 004                              223  COM
# Martinair Holland Flight 138                      191  COM
# Mexicana Flight 940                               167  COM
# Nigeria Airways (JY-ADO)                          176  COM
# Nigeria Airways Flight 2120                       261  COM
# Pakistan International Airlines Flight 268        167  COM
# Pan Am Flight 103                                 270  INB
# Pan Am Flight 1736 and KLM Flight 4805            583  COM
# Pulkovo Flight 612                                170  COM
# Saudi Arabian Flight 763 and                      349
# Saudia Flight 163                                 301  COM
# Surinam Airways Flight 764                        176  COM
# Swissair Flight 111                               229  COM
# TAM Airlines Flight 3054                          199  COM
# TWA Flight 800                                    230  COM
# Turkish Airlines Flight 981                       346  COM
# Union de Transportes Aériens Flight 772           170  INB
# United Airlines Flight 175                        965  INH
# West Caribbean Airways Flight 708                 160  COM

# %% [markdown]
# ### That's most of the wrangling as was done with DataWrangler, there are a few more optional steps:
# * want the manufacturer e.g. Beoing?
# * remove 'extract' & 'extract1'?
# * rename columns ('split')
# * extract year into new column
# * export e.g. df.to_csv(file_name, sep=',')

# %%
#data.reset_index()

# %% [markdown]
# # Part 2
#
# ## Wait there's more:
#
# Bad, bad data
#
# This data has been deliberately damaged (sorry)
#
# Some are obvious, some are subtle (some were already there... e.g. look for 'Â')
#
# ### See if you can find them

# %%
# start with a summary table
data.describe()
# Out:
# split       Casualties            Circumstances Country Crew        Date  \
# count               58                       58      58   58          58
# unique               1                        3      36   20          56
# top     Extremely High  Bad Visibility by Night      US   14  2001-09-11
# freq                58                       49       7    7           3
#
# split  Ground    Latitude                  Location    Longitude  \
# count      58          58                        58           58
# unique     14          57                        57           57
# top         0  40.7143528  New York - New York - US  -74.0059731
# freq       45           2                         2            2
#
# split          Notes Passengers Phase    Reason Total Dead Type
# count             58         58    58        58         58   58
# unique             3         50     5         2         51    7
# top     No survivors        156   ENR  Accident        178  COM
# freq              46          3    38        50          2   48

# %% [markdown]
# ### describe() shows:
#
# * count - we can see that there are 58 records across the board, no surprise (what would it mean if there were non 58s?)
# * unique - looks like all the 'Casualties' are identical (unique = 1, i.e. all 'Extremely High'), maybe this column is redundant?
# * top - interesting, there were two major disasters in the exact same place? Check dates?
# * freq - also interesting, 3 times there were 156 passengers on flights... superstitious? Or is it bad data?
#
# So some clues here, dig deeper:

# %%
#We can also describe individual columns:
data['Crew'].describe()
# Out:
# count     58
# unique    20
# top       14
# freq       7
# Name: Crew, dtype: object

# %%
# nothing new here, the most common number crew size is 14 (7 times)
# what's the biggest crew?
data['Crew'].max()
# Out:
# '9'

# %% [markdown]
# Why 9 (or even '9')?
#
# How can this max be less than 14?
#
# Are these even numbers?

# %%
data['Crew'].mean() # expecting ~15, they were all big planes?
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-941d9d0a4aeb> in <cell line: 0>()
# ----> 1 data['Crew'].mean() # expecting ~15, they were all big planes?
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/series.py in mean(self, axis, skipna, numeric_only, **kwargs)
#    6547         **kwargs,
#    6548     ):
# -> 6549         return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#    6550
#    6551     @doc(make_doc("median", ndim=1))
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in mean(self, axis, skipna, numeric_only, **kwargs)
#   12418         **kwargs,
#   12419     ) -> Series | float:
# > 12420         return self._stat_function(
#   12421             "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   12422         )
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in _stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   12375         validate_bool_kwarg(skipna, "skipna", none_allowed=False)
#   12376
# > 12377         return self._reduce(
#   12378             func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   12379         )
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    6455                     "with non-numeric dtypes."
#    6456                 )
# -> 6457             return op(delegate, skipna=skipna, **kwds)
#    6458
#    6459     @Appender(make_doc("any", ndim=1))
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/nanops.py in f(values, axis, skipna, **kwds)
#     145                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     146             else:
# --> 147                 result = alt(values, axis=axis, skipna=skipna, **kwds)
#     148
#     149             return result
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/nanops.py in new_func(values, axis, skipna, mask, **kwargs)
#     402             mask = isna(values)
#     403
# --> 404         result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     405
#     406         if datetimelike:
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/nanops.py in nanmean(values, axis, skipna, mask)
#     718     count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
#     719     the_sum = values.sum(axis, dtype=dtype_sum)
# --> 720     the_sum = _ensure_numeric(the_sum)
#     721
#     722     if axis is not None and getattr(the_sum, "ndim", False):
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/nanops.py in _ensure_numeric(x)
#    1699         if isinstance(x, str):
#    1700             # GH#44008, GH#36703 avoid casting e.g. strings to numeric
# -> 1701             raise TypeError(f"Could not convert string '{x}' to numeric")
#    1702         try:
#    1703             x = float(x)
#
# TypeError: Could not convert string '10510913012222320137711139688181141215191414116151287161815102223111098614121623103314914618111498' to numeric

# %% [markdown]
# This is weird
#
# If they are numbers it should be higher
#
# If they are not numbers, what does mean 'mean'?

# %%
data[data['Crew'] == 14] # look at all the crew = 14 planes, should be 7
# Out:
# Empty DataFrame
# Columns: [Casualties, Circumstances, Country, Crew, Date, Ground, Latitude, Location, Longitude, Notes, Passengers, Phase, Reason, Total Dead, Type]
# Index: []

# %%
# there are none... try this:
data[data['Crew'] == '14']
# Out:
# split                                        Casualties  \
# extract
# British Airways Flight 476 and           Extremely High
# China Airlines Flight 676                Extremely High
# China Northwest Airlines Flight 2303     Extremely High
# Nigeria Airways Flight 2120              Extremely High
# Saudia Flight 163                        Extremely High
# Swissair Flight 111                      Extremely High
# Union de Transportes Aériens Flight 772  Extremely High
#
# split                                              Circumstances  \
# extract
# British Airways Flight 476 and           Bad Visibility by Night
# China Airlines Flight 676                Bad Visibility by Night
# China Northwest Airlines Flight 2303     Bad Visibility by Night
# Nigeria Airways Flight 2120              Bad Visibility by Night
# Saudia Flight 163                        Bad Visibility by Night
# Swissair Flight 111                        Bad Visibility by Day
# Union de Transportes Aériens Flight 772  Bad Visibility by Night
#
# split                                         Country Crew        Date Ground  \
# extract
# British Airways Flight 476 and                Croatia   14  1976-09-10      1
# China Airlines Flight 676                       China   14  1998-02-16      7
# China Northwest Airlines Flight 2303            China   14  1984-06-06      0
# Nigeria Airways Flight 2120              Saudi Arabia   14  1991-07-11      0
# Saudia Flight 163                        Saudi Arabia   14  1980-08-19      0
# Swissair Flight 111                            Canada   14  1998-09-02      0
# Union de Transportes Aériens Flight 772         Niger   14  1989-19-09      0
#
# split                                      Latitude  \
# extract
# British Airways Flight 476 and           45.8839523
# China Airlines Flight 676                25.0492632
# China Northwest Airlines Flight 2303      34.341568
# Nigeria Airways Flight 2120              21.5433333
# Saudia Flight 163                        24.7116667
# Swissair Flight 111                      44.4927778
# Union de Transportes Aériens Flight 772  18.9546137
#
# split                                                                        Location  \
# extract
# British Airways Flight 476 and                                      Vrbovec - Croatia
# China Airlines Flight 676                                     Dayuan - Taiwan - China
# China Northwest Airlines Flight 2303                                     Xian - China
# Nigeria Airways Flight 2120                                     Jeddah - Saudi Arabia
# Saudia Flight 163                                               Riyadh - Saudi Arabia
# Swissair Flight 111                      Atlantic Ocean - Peggys Cove - N.S. - Canada
# Union de Transportes Aériens Flight 772                                Tenere - Niger
#
# split                                     Longitude         Notes Passengers  \
# extract
# British Airways Flight 476 and            16.416766  No survivors        162
# China Airlines Flight 676                121.193945  No survivors        182
# China Northwest Airlines Flight 2303     108.940175  No survivors        146
# Nigeria Airways Flight 2120              39.1727778  No survivors        247
# Saudia Flight 163                        46.7241667  No survivors        287
# Swissair Flight 111                        -63.9175  No survivors        215
# Union de Transportes Aériens Flight 772  10.9134609  No survivors        156
#
# split                                   Phase    Reason Total Dead Type
# extract
# British Airways Flight 476 and            ENR  Accident        177  COM
# China Airlines Flight 676                 APR  Accident        202  COM
# China Northwest Airlines Flight 2303      ENR  Accident        150  COM
# Nigeria Airways Flight 2120               APR  Accident        261  COM
# Saudia Flight 163                         ENR  Accident        301  COM
# Swissair Flight 111                       ENR  Accident        229  COM
# Union de Transportes Aériens Flight 772   ENR    Attack        170  INB

# %%
# so there's a clue, 14 vs '14'
# what are these data types anyway?
data.dtypes
# Out:
# split
# Casualties       object
# Circumstances    object
# Country          object
# Crew             object
# Date             object
# Ground           object
# Latitude         object
# Location         object
# Longitude        object
# Notes            object
# Passengers       object
# Phase            object
# Reason           object
# Total Dead       object
# Type             object
# dtype: object

# %% [markdown]
# ### All data are of type object...
# ### Overruled:

# %%
data = data.astype({'Crew': 'int32','Ground': 'int32','Passengers': 'int32','Total Dead': 'int32', 'Latitude': 'float','Longitude': 'float'})

# this is a bit brutal, can you convert when data is loaded?

# %%
data.dtypes
# Out:
# split
# Casualties        object
# Circumstances     object
# Country           object
# Crew               int32
# Date              object
# Ground             int32
# Latitude         float64
# Location          object
# Longitude        float64
# Notes             object
# Passengers         int32
# Phase             object
# Reason            object
# Total Dead         int32
# Type              object
# dtype: object

# %%
# so now we have some numbers (int & float)
data.describe()
# Out:
# split        Crew       Ground    Latitude   Longitude  Passengers  \
# count   58.000000    58.000000   58.000000   58.000000   58.000000
# mean    15.396552    51.017241   25.337876   21.807698  200.724138
# std     22.838825   240.369561   28.037558   74.024614   87.867283
# min      0.000000     0.000000 -100.423368 -100.423368    0.000000
# 25%      9.000000     0.000000   13.835361  -52.617466  159.000000
# 50%     12.000000     0.000000   30.489219   15.865327  181.000000
# 75%     15.000000     0.000000   41.964744   76.751146  241.500000
# max    181.000000  1600.000000   55.755826  167.075701  560.000000
#
# split   Total Dead
# count    58.000000
# mean    257.155172
# std     232.558071
# min       0.000000
# 25%     171.750000
# 50%     195.000000
# 75%     263.250000
# max    1692.000000

# %% [markdown]
# ### Better, more information, describe() now shows:
# * count - as above, all 58
# * mean - crew ~15, seems OK, but mean lat & long doesn't mean much... or does it?
# * std - Standard Deviation
# * min - now we see some problems, zero crew? Was this a way to code a hijacking, or is it missing, or should it be 10, 20, 30?
# * 25, 50 & 75% are quartiles...
# * max - crew 181, no way! 1692 dead, no plane is that big... or could this be Lockerbie, i.e. plane hit town
#
# Let's investigate the crew data:

# %%
data[data['Crew'] > 20] # try also e.g. < 10
# Out:
# split                                       Casualties  \
# extract
# Air India Flight 182                    Extremely High
# Air India Flight 855                    Extremely High
# Avianca Flight 011                      Extremely High
# Korean Air Flight 801                   Extremely High
# Korean Air Lines Flight 007             Extremely High
# Pan Am Flight 1736 and KLM Flight 4805  Extremely High
# Saudi Arabian Flight 763 and            Extremely High
#
# split                                             Circumstances  Country  \
# extract
# Air India Flight 182                    Bad Visibility by Night  Ireland
# Air India Flight 855                    Bad Visibility by Night    India
# Avianca Flight 011                      Bad Visibility by Night    Spain
# Korean Air Flight 801                   Bad Visibility by Night       US
# Korean Air Lines Flight 007             Bad Visibility by Night   Russia
# Pan Am Flight 1736 and KLM Flight 4805    Bad Visibility by Day    Spain
# Saudi Arabian Flight 763 and            Bad Visibility by Night    India
#
# split                                   Crew        Date  Ground   Latitude  \
# extract
# Air India Flight 182                      22  1985-06-23       0  51.896892
# Air India Flight 855                      23  1978-01-01       0  19.075984
# Avianca Flight 011                       181  1983-11-27       0  40.416775
# Korean Air Flight 801                     22  1997-08-06       0  13.466681
# Korean Air Lines Flight 007               23  1983-09-01       0  46.250000
# Pan Am Flight 1736 and KLM Flight 4805    23  1977-03-27       0  28.291564
# Saudi Arabian Flight 763 and              33  1996-11-12       0  28.600000
#
# split                                                                 Location  \
# extract
# Air India Flight 182                           Atlantic Ocean - Cork - Ireland
# Air India Flight 855                             Arabian Sea -  Mumbai - India
# Avianca Flight 011                                              Madrid - Spain
# Korean Air Flight 801                                         Asan - Guam - US
# Korean Air Lines Flight 007             Sea of Japan - Moneron Island - Russia
# Pan Am Flight 1736 and KLM Flight 4805                        Tenerife - Spain
# Saudi Arabian Flight 763 and                             Charkhi Dadri - India
#
# split                                    Longitude           Notes  \
# extract
# Air India Flight 182                     -8.486316    No survivors
# Air India Flight 855                     72.877656    No survivors
# Avianca Flight 011                       -3.703790  Some survivors
# Korean Air Flight 801                   144.745468  Some survivors
# Korean Air Lines Flight 007             141.233333    No survivors
# Pan Am Flight 1736 and KLM Flight 4805  -16.629130  Some survivors
# Saudi Arabian Flight 763 and             76.266700    No survivors
#
# split                                   Passengers Phase    Reason  \
# extract
# Air India Flight 182                           307   ENR    Attack
# Air India Flight 855                           190   ENR  Accident
# Avianca Flight 011                             162   APR  Accident
# Korean Air Flight 801                          206   APR  Accident
# Korean Air Lines Flight 007                    246   ENR    Attack
# Pan Am Flight 1736 and KLM Flight 4805         560   TOF  Accident
# Saudi Arabian Flight 763 and                   316   ENR  Accident
#
# split                                   Total Dead Type
# extract
# Air India Flight 182                           329  INB
# Air India Flight 855                           213  COM
# Avianca Flight 011                             181  COM
# Korean Air Flight 801                          228  COM
# Korean Air Lines Flight 007                    269  EXS
# Pan Am Flight 1736 and KLM Flight 4805         583  COM
# Saudi Arabian Flight 763 and                   349

# %% [markdown]
# So Boeing 747s have large crews...
# #### 33 crew is that possible? Or is that two flights?
#
# #### 181 crew? Same value as for 'Total dead', can you derive crew from dead minus passengers?
# (or does 'Some survivors' corrupt the maths?)
#
#
# # Another way to explore... plot that data:

# %%
# %matplotlib inline
# notebook majik to display plots in the notebook

data[['Crew','Passengers']].plot(x= 'Crew',y= 'Passengers',kind= 'scatter')
# Out:
# <Axes: xlabel='Crew', ylabel='Passengers'>

# %% [markdown]
# #### And there's the extreme outlier
# #### Are there any others?

# %%
# so how to put a number to an outlier?
data['Crew'].max() # works, now that they are numbers
# Out:
# 181

# %%
data[data['Crew']==data['Crew'].max()]
# Out:
# split                   Casualties            Circumstances Country  Crew  \
# extract
# Avianca Flight 011  Extremely High  Bad Visibility by Night   Spain   181
#
# split                     Date  Ground   Latitude        Location  Longitude  \
# extract
# Avianca Flight 011  1983-11-27       0  40.416775  Madrid - Spain   -3.70379
#
# split                        Notes  Passengers Phase    Reason  Total Dead  \
# extract
# Avianca Flight 011  Some survivors         162   APR  Accident         181
#
# split              Type
# extract
# Avianca Flight 011  COM

# %% [markdown]
# ## Plotting non-numeric data

# %%
data['Phase'].value_counts().plot(kind='bar')
# you can guess some of these codes
# ENR = en route?
# APR = Aproach
# Takeoff, Landing
# ICL?
# Out:
# <Axes: xlabel='Phase'>

# %%
# not much point in plotting Casualties... so what the hey
data['Casualties'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Casualties'>

# %% [markdown]
# # To do: find any other data problems (there are about 10)
#
# <br>
#
# ![](https://media1.popsugar-assets.com/files/thumbor/yjoSwHRBZ4MpTO3TN6lvI_gsKMI/fit-in/2048xorig/filters:format_auto-!!-:strip_icc-!!-/2016/03/02/901/n/1922283/01f64bd801c06153_game4/i/When-Everyone-Trying-Talk-You-Youre-Too-Hungry-Care.gif)
#
# #### Post your suspected bad data cases in Moodle discussion forums, how you found it, and suggested fixes
# (one or two each, share the load)

# %%
# go crazy

# %% [markdown]
# #### Can data be 'typed' as it is read in?
# (yes see 'dtype')
# https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html
# #### What happens if this process encounters bad data?
#
# #### So why is 'Crew' max '9' above?
#
# #### When a plane hits another plane is that one record or two?
#
# #### Can DataWrangler do this sort of wrangling?
